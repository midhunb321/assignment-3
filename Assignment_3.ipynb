# %% [markdown]
# Assignment 3

# %%
import pandas as pd

# %%
df = pd.read_csv('Students_Performance.csv')

# %% [markdown]
# A.Males and Females participated in the test.

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
gender_counts = df['gender'].value_counts()
print(gender_counts)
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# B.student's parental level of education.

# %%
parental_education_counts = df['parental level of education'].value_counts()
print(parental_education_counts)
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# C.who scores the most on average for math, reading and
# writing based on
# i. Gender
# ii. Test preparation course

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
average_scores = df.groupby(['gender', 'test preparation course'])[['math score', 'reading score', 'writing score']].mean()
print(average_scores)
# Out:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 67.108696      77.375000      78.793478
#        none                      61.320359      69.955090      68.982036
# male   completed                 72.988506      70.793103      70.339080
#        none                      66.467532      62.581169      59.551948

# %% [markdown]
# d. Scoring variation based on gender and test preparation course:

# %%
score_variance = df.groupby(['gender', 'test preparation course'])[['math score', 'reading score', 'writing score']].var()
print(score_variance)
# Out:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                208.173913     161.175546     149.836897
#        none                     272.602767     214.241220     225.495172
# male   completed                197.098133     185.297987     166.098233
#        none                     205.513600     184.843553     181.394687

# %%
std_deviation = df.groupby(['gender', 'test preparation course']).std()[['math score', 'reading score', 'writing score']]
print(std_deviation)
# Out:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 14.428233      12.695493      12.240788
#        none                      16.510686      14.636981      15.016497
# male   completed                 14.039164      13.612420      12.887910
#        none                      14.335746      13.595718      13.468284
# <ipython-input-16-24df06de6808>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   std_deviation = df.groupby(['gender', 'test preparation course']).std()[['math score', 'reading score', 'writing score']]

# %% [markdown]
# e. Help the management give bonus points to the top 25% of students based on their math score:

# %%
import numpy as np

# %%
math_scores = df['math score']
cutoff_score = np.percentile(math_scores, 75)


top_25_percent_students = df[df['math score'] >= cutoff_score]
bonus_points = 5
top_25_percent_students['bonus_points'] = bonus_points
top_25_percent_students.to_csv('students_with_bonus.csv', index=False)
# Out:
# <ipython-input-24-85df5193cd55>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_25_percent_students['bonus_points'] = bonus_points

# %%
df1 = pd.read_csv('students_with_bonus.csv')

# %%
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group A                 high school  free/reduced
# 1    female        group B             master's degree  free/reduced
# 2    female        group B           bachelor's degree  free/reduced
# 3    female        group B             master's degree      standard
# 4    female        group B                 high school      standard
# ..      ...            ...                         ...           ...
# 250    male        group E                some college      standard
# 251    male        group A                some college      standard
# 252    male        group D                some college      standard
# 253    male        group E          associate's degree  free/reduced
# 254    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df1.head(20)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group A                 high school  free/reduced
# 1   female        group B             master's degree  free/reduced
# 2   female        group B           bachelor's degree  free/reduced
# 3   female        group B             master's degree      standard
# 4   female        group B                 high school      standard
# 5   female        group C           bachelor's degree      standard
# 6   female        group C           bachelor's degree      standard
# 7   female        group C                some college  free/reduced
# 8   female        group C            some high school      standard
# 9   female        group C            some high school      standard
# 10  female        group D          associate's degree  free/reduced
# 11  female        group D             master's degree      standard
# 12  female        group D                some college      standard
# ...

# %% [markdown]
# Case Study on Testing of Hypothesis

# %% [markdown]
# Question:2,a

# %%
import pandas as pd
df2=pd.read_csv('Sales_add.csv')

# %%
df2
# Out:
#        Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0    Month-1  Region - A  Manager - A                          132921
# 1    Month-2  Region - A  Manager - C                          149559
# 2    Month-3  Region - B  Manager - A                          146278
# 3    Month-4  Region - B  Manager - B                          152167
# 4    Month-5  Region - C  Manager - B                          159525
# 5    Month-6  Region - A  Manager - B                          137163
# 6    Month-7  Region - C  Manager - C                          130625
# 7    Month-8  Region - A  Manager - A                          131140
# 8    Month-9  Region - B  Manager - C                          171259
# 9   Month-10  Region - C  Manager - B                          141956
# 10  Month-11  Region - B  Manager - C                          159339
# 11  Month-12  Region - A  Manager - A                          178939
# ...

# %%
df2.columns
# Out:
# Index(['Month', 'Region', 'Manager', 'Sales_before_digital_add(in $)',
#        'Sales_After_digital_add(in $)'],
#       dtype='object')

# %%
sales_before = df2['Sales_before_digital_add(in $)']
sales_after = df2['Sales_After_digital_add(in $)']

# %%
from scipy import stats

t_stat, p_value = stats.ttest_rel(sales_before, sales_after)

# %%
alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis. There is a significant increase in sales after implementing digital marketing.")
else:
    print("Fail to reject the null hypothesis. There is no significant increase in sales after implementing digital marketing.")
# Out:
# Reject the null hypothesis. There is a significant increase in sales after implementing digital marketing.

# %% [markdown]
# Qn2:b

# %%
df2.columns
# Out:
# Index(['Month', 'Region', 'Manager', 'Sales_before_digital_add(in $)',
#        'Sales_After_digital_add(in $)'],
#       dtype='object')

# %%
region = df2['Region']
manager = df2['Manager']

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(region, manager)
chi2, p, dof, expected = chi2_contingency(contingency_table)

# %%
alpha = 0.05

if p < alpha:
    print("Reject the null hypothesis. Region and Manager are dependent.")
else:
    print("Fail to reject the null hypothesis. Region and Manager are independent.")
# Out:
# Fail to reject the null hypothesis. Region and Manager are independent.
